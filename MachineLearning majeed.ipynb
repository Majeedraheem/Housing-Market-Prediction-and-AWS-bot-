# %%
# importing libraries
import numpy as np
import pandas as pd
from pathlib import Path
import hvplot.pandas
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
import time
from sklearn.metrics import r2_score
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.metrics import MeanSquaredError
from pandas.tseries.offsets import DateOffset
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from bokeh.models.formatters import NumeralTickFormatter
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/gk/537qy50d4ls5vppc09_8xb0r0000gn/T/ipykernel_7927/4245016037.py in <module>
#       9 from sklearn.metrics import r2_score
#      10 from sklearn.preprocessing import StandardScaler
# ---> 11 from tensorflow.keras.layers import Dense
#      12 from tensorflow.keras.models import Sequential
#      13 from tensorflow.keras.metrics import MeanSquaredError
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
all_values = pd.read_csv(Path("Resources/all_values.csv"))
all_values['date'] = pd.to_datetime(all_values['date'], format='%Y-%m')
all_values.set_index('date', inplace=True)
#all_values.index = all_values.index.strftime('%Y-%m')

# %%
scaler_all = StandardScaler()
all_scaler = scaler_all.fit(all_values)
all_values_scaled = all_scaler.transform(all_values)

all_values_scaled_df = pd.DataFrame(all_values_scaled, columns=all_values.columns, index=all_values.index)
all_values_scaled_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/gk/537qy50d4ls5vppc09_8xb0r0000gn/T/ipykernel_7927/1970887175.py in <module>
# ----> 1 scaler_all = StandardScaler()
#       2 all_scaler = scaler_all.fit(all_values)
#       3 all_values_scaled = all_scaler.transform(all_values)
#       4
#       5 all_values_scaled_df = pd.DataFrame(all_values_scaled, columns=all_values.columns, index=all_values.index)
#
# NameError: name 'StandardScaler' is not defined

# %%
y = all_values["Composite"]

# %%
X = all_values.drop(columns = "Composite")

# %%
y
# Out:
# date
# 2008-06-01    319000.0
# 2008-07-01    317800.0
# 2008-08-01    316800.0
# 2008-09-01    315900.0
# 2008-10-01    312700.0
#                 ...
# 2022-09-01    911100.0
# 2022-10-01    898600.0
# 2022-11-01    886900.0
# 2022-12-01    874300.0
# 2023-01-01    859300.0
# Name: Composite, Length: 176, dtype: float64

# %%
X
# Out:
#             Lumber       Wood        XHB        ITB  Bank Rate  All-items 8  \
# date
# 2008-06-01  254.96  48.860001  20.260000  17.610001       3.25        114.9
# 2008-07-01  261.80  48.529999  18.690001  16.480000       3.25        115.4
# 2008-08-01  270.10  49.169998  19.730000  16.530001       3.25        115.4
# 2008-09-01  240.70  49.919998  22.370001  19.750000       3.25        115.5
# 2008-10-01  199.50  44.180000  20.110001  18.150000       2.75        114.7
# ...            ...        ...        ...        ...        ...          ...
# 2022-09-01  567.00  77.040001  62.630001  58.130001       3.50        153.0
# 2022-10-01  535.30  71.540001  59.320000  56.970001       4.00        153.8
# 2022-11-01  460.00  76.849998  62.830002  60.880001       4.00        154.3
# 2022-12-01  425.60  76.900002  63.290001  62.840000       4.50        154.3
# 2023-01-01  527.70  78.440002  69.449997  69.570000       4.75        154.7
#
#              Food  Shelter  Household operations, furnishings and equipment  \
# date
# 2008-06-01  115.2    122.3                                            104.3
# 2008-07-01  116.0    123.3                                            104.5
# 2008-08-01  116.8    123.8                                            104.5
# 2008-09-01  118.0    123.1                                            105.4
# 2008-10-01  118.5    123.2                                            105.2
# ...           ...      ...                                              ...
# 2022-09-01  175.5    164.9                                            132.5
# 2022-10-01  176.4    166.2                                            132.6
# 2022-11-01  177.8    167.2                                            132.8
# 2022-12-01  178.7    167.8                                            132.7
# 2023-01-01  180.4    168.0                                            132.2
#
#             Clothing and footwear  Transportation  Health and personal care  \
# date
# 2008-06-01                   94.0           124.0                     108.3
# 2008-07-01                   94.8           124.0                     108.4
# 2008-08-01                   94.3           122.4                     109.3
# 2008-09-01                   94.0           122.3                     109.2
# 2008-10-01                   92.7           118.3                     109.3
# ...                           ...             ...                       ...
# 2022-09-01                   95.5           168.4                     139.5
# 2022-10-01                   95.8           170.1                     140.2
# 2022-11-01                   95.2           170.1                     141.2
# 2022-12-01                   96.1           168.6                     142.0
# 2023-01-01                   95.8           168.2                     142.7
#
#             Recreation, education and reading  \
# date
# 2008-06-01                              102.3
# 2008-07-01                              102.2
# 2008-08-01                              102.5
# 2008-09-01                              102.4
# 2008-10-01                              102.2
# ...                                       ...
# 2022-09-01                              124.6
# 2022-10-01                              124.6
# 2022-11-01                              124.8
# 2022-12-01                              124.6
# 2023-01-01                              124.6
#
#             Alcoholic beverages, tobacco products and recreational cannabis  \
# date
# 2008-06-01                                              127.7
# 2008-07-01                                              127.6
# 2008-08-01                                              127.5
# 2008-09-01                                              128.0
# 2008-10-01                                              128.0
# ...                                                       ...
# 2022-09-01                                              182.7
# 2022-10-01                                              183.7
# 2022-11-01                                              184.7
# 2022-12-01                                              185.2
# 2023-01-01                                              186.5
#
#             All-items excluding food  All-items excluding food and energy
# date
# 2008-06-01                     114.9                                110.3
# 2008-07-01                     115.2                                110.4
# 2008-08-01                     115.0                                110.6
# 2008-09-01                     115.0                                110.6
# 2008-10-01                     113.9                                110.4
# ...                              ...                                  ...
# 2022-09-01                     148.7                                143.5
# 2022-10-01                     149.6                                143.9
# 2022-11-01                     150.0                                144.3
# 2022-12-01                     149.8                                144.8
# 2023-01-01                     149.9                                145.0
#
# [176 rows x 16 columns]

# %%
training_begin = X.index.min()
print(training_begin)
training_end = X.index.min() + DateOffset(months=50)
print(training_end)
# Out:
# 2008-06-01 00:00:00
# 2012-08-01 00:00:00

# %%
X_train = X.loc[training_begin:training_end]
y_train = y.loc[training_begin:training_end]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/gk/537qy50d4ls5vppc09_8xb0r0000gn/T/ipykernel_7927/3446686.py in <module>
# ----> 1 X_train = X.loc[training_begin:training_end]
#       2 y_train = y.loc[training_begin:training_end]
#
# NameError: name 'X' is not defined

# %%
X_test = X.loc[training_end:]
y_test = y.loc[training_end:]

# %%
X_test
# Out:
#             Lumber       Wood        XHB        ITB  Bank Rate  All-items 8  \
# date
# 2012-08-01  315.00  39.110001  23.590000  18.170000       1.25        121.7
# 2012-09-01  279.40  41.709999  25.930000  20.570000       1.25        121.9
# 2012-10-01  328.72  41.919998  26.170000  20.879999       1.25        122.2
# 2012-11-01  340.50  42.730000  26.830000  21.080000       1.25        122.1
# 2012-12-01  391.30  45.240002  26.889999  21.450001       1.25        122.0
# ...            ...        ...        ...        ...        ...          ...
# 2022-09-01  567.00  77.040001  62.630001  58.130001       3.50        153.0
# 2022-10-01  535.30  71.540001  59.320000  56.970001       4.00        153.8
# 2022-11-01  460.00  76.849998  62.830002  60.880001       4.00        154.3
# 2022-12-01  425.60  76.900002  63.290001  62.840000       4.50        154.3
# 2023-01-01  527.70  78.440002  69.449997  69.570000       4.75        154.7
#
#              Food  Shelter  Household operations, furnishings and equipment  \
# date
# 2012-08-01  131.4    127.4                                            112.9
# 2012-09-01  131.2    127.2                                            113.2
# 2012-10-01  131.7    127.6                                            113.4
# 2012-11-01  131.7    127.5                                            113.6
# 2012-12-01  131.7    127.5                                            113.6
# ...           ...      ...                                              ...
# 2022-09-01  175.5    164.9                                            132.5
# 2022-10-01  176.4    166.2                                            132.6
# 2022-11-01  177.8    167.2                                            132.8
# 2022-12-01  178.7    167.8                                            132.7
# 2023-01-01  180.4    168.0                                            132.2
#
#             Clothing and footwear  Transportation  Health and personal care  \
# date
# 2012-08-01                   90.9           127.6                     119.6
# 2012-09-01                   91.3           128.7                     118.5
# 2012-10-01                   91.6           129.3                     118.8
# 2012-11-01                   91.8           128.2                     118.7
# 2012-12-01                   92.0           127.7                     118.8
# ...                           ...             ...                       ...
# 2022-09-01                   95.5           168.4                     139.5
# 2022-10-01                   95.8           170.1                     140.2
# 2022-11-01                   95.2           170.1                     141.2
# 2022-12-01                   96.1           168.6                     142.0
# 2023-01-01                   95.8           168.2                     142.7
#
#             Recreation, education and reading  \
# date
# 2012-08-01                              106.2
# 2012-09-01                              106.0
# 2012-10-01                              105.9
# 2012-11-01                              106.4
# 2012-12-01                              106.4
# ...                                       ...
# 2022-09-01                              124.6
# 2022-10-01                              124.6
# 2022-11-01                              124.8
# 2022-12-01                              124.6
# 2023-01-01                              124.6
#
#             Alcoholic beverages, tobacco products and recreational cannabis  \
# date
# 2012-08-01                                              137.9
# 2012-09-01                                              137.7
# 2012-10-01                                              137.8
# 2012-11-01                                              138.3
# 2012-12-01                                              138.3
# ...                                                       ...
# 2022-09-01                                              182.7
# 2022-10-01                                              183.7
# 2022-11-01                                              184.7
# 2022-12-01                                              185.2
# 2023-01-01                                              186.5
#
#             All-items excluding food  All-items excluding food and energy
# date
# 2012-08-01                     119.8                                116.1
# 2012-09-01                     120.0                                116.2
# 2012-10-01                     120.3                                116.3
# 2012-11-01                     120.2                                116.5
# 2012-12-01                     120.1                                116.5
# ...                              ...                                  ...
# 2022-09-01                     148.7                                143.5
# 2022-10-01                     149.6                                143.9
# 2022-11-01                     150.0                                144.3
# 2022-12-01                     149.8                                144.8
# 2023-01-01                     149.9                                145.0
#
# [126 rows x 16 columns]

# %%
x_scaler = MinMaxScaler()
y_scaler = MinMaxScaler()
X_train_scaled = x_scaler.fit_transform(X_train)
X_test_scaled = x_scaler.transform(X_test)
y_train_scaled = y_scaler.fit_transform(y_train.reshape(-1, 1)).ravel()
y_test_scaled = y_scaler.transform(y_test.reshape(-1, 1)).ravel()

# %%
X_test_scaled
# Out:
# array([[ 1.44281847, -0.21564029,  2.17130449, ...,  1.52531673,
#          1.48414205,  1.54543488],
#        [ 0.61039675,  0.18477844,  2.99154911, ...,  1.46194308,
#          1.56177409,  1.59794466],
#        [ 1.76362819,  0.21711982,  3.07567676, ...,  1.4936299 ,
#          1.67822216,  1.65045444],
#        ...,
#        [ 4.83330021,  5.59659567, 15.92617649, ..., 16.35475041,
#         13.20658094, 16.3531927 ],
#        [ 4.02893764,  5.60429665, 16.0874208 , ..., 16.51318453,
#         13.1289489 , 16.6157416 ],
#        [ 6.41630444,  5.84146793, 18.24669583, ..., 16.92511324,
#         13.16776492, 16.72076116]])

# %%
from sklearn.neural_network import MLPRegressor
mlp = MLPRegressor(hidden_layer_sizes=(1000, 1000), activation='relu', random_state=42)
mlp.fit(X_train, y_train)
# Out:
# MLPRegressor(hidden_layer_sizes=(1000, 1000), random_state=42)

# %%
mlp.fit(X_train_scaled, y_train)
# Out:
# /Users/mac/anaconda3/envs/dev/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# MLPRegressor(hidden_layer_sizes=(1000, 1000), random_state=42)

# %%
y_pred = mlp.predict(X_test)
# Out:
# /Users/mac/anaconda3/envs/dev/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   f"X has feature names, but {self.__class__.__name__} was fitted without"

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 395033065175129.06

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/gk/537qy50d4ls5vppc09_8xb0r0000gn/T/ipykernel_7927/4287140100.py in <module>
#       3 from sklearn.inspection import permutation_importance
#       4 model = RandomForestRegressor(n_estimators=100, random_state=40)
# ----> 5 model.fit(X_train,y_train)
#
# NameError: name 'X_train' is not defined

# %%
# Get the feature importance scores
importance_scores = results.importances_mean
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/gk/537qy50d4ls5vppc09_8xb0r0000gn/T/ipykernel_7927/2041426213.py in <module>
#       1 # Get the feature importance scores
# ----> 2 importance_scores = results.importances_mean
#
# NameError: name 'results' is not defined

# %%
feature_names = all_values.columns.tolist()

# %%
for feature_name, importance_score in zip(feature_names, importance_scores):
    print(f"{feature_name}: {importance_score}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/gk/537qy50d4ls5vppc09_8xb0r0000gn/T/ipykernel_8010/455296199.py in <module>
# ----> 1 for feature_name, importance_score in zip(feature_names, importance_scores):
#       2     print(f"{feature_name}: {importance_score}")
#
# NameError: name 'feature_names' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/gk/537qy50d4ls5vppc09_8xb0r0000gn/T/ipykernel_7927/1388039462.py in <module>
# ----> 1 feature_importances = dict(zip(feature_names, importances))
#       2
#       3 # Set a threshold for feature importance (e.g., 0.05)
#       4 threshold = 0.05
#       5
#
# NameError: name 'feature_names' is not defined
