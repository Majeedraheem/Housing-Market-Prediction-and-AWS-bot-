# %%
# importing libraries
import numpy as np
import pandas as pd
from pathlib import Path
import hvplot.pandas
from bokeh.models.formatters import NumeralTickFormatter
#import warnings
#warnings.filterwarnings("ignore", category=FutureWarning)
#import time

# %%
def import_region_data(path):
    file = Path(path)
    region_name = file.name.split('.')[0]
    region_data_df = pd.read_csv(file, infer_datetime_format=True, parse_dates=True, index_col='Date')
    region_data_df.index = region_data_df.index.strftime('%Y-%m')
    # region_data_df['Region'] = region_name
    region_cols = region_data_df.columns.tolist()
    region_cols[0]
    region_cols_adj = [cols for cols in region_cols if cols.find('HPI') < 0]
    region_data_df = region_data_df[region_cols_adj]
    # region_cols_rename = [{col:col+'_'+region_name} 
    for col in region_data_df.columns.tolist():
        # region_data_df.rename(columns=region_cols_rename[0], inplace=True)
        region_data_df.rename(columns={col:col+'_'+region_name}, inplace=True)
    return region_data_df

# %%
bancroft_df = import_region_data('Resources/BANCROFT_AND_AREA.csv')
barrie_df = import_region_data('Resources/BARRIE_AND_AREA.csv')
brantford_df = import_region_data('Resources/BRANTFORD_AND_AREA.csv')
cambridge_df = import_region_data('Resources/CAMBRIDGE.csv')
toronto_df = import_region_data('Resources/GREATER_TORONTO.csv')
grey_bruce_owen_sound_df = import_region_data('Resources/GREY_BRUCE_OWEN_SOUND.csv')
guelph_df = import_region_data('Resources/GUELPH_AND_DISTRICT.csv')
hamilton_burlington_df = import_region_data('Resources/HAMILTON_BURLINGTON.csv')
huron_perth_df = import_region_data('Resources/HURON_PERTH.csv')
kawartha_df = import_region_data('Resources/KAWARTHA_LAKES.csv')
kingston_df = import_region_data('Resources/KINGSTON_AND_AREA.csv')
kitchener_waterloo_df = import_region_data('Resources/KITCHENER_WATERLOO.csv')
lakelands_df = import_region_data('Resources/LAKELANDS.csv')
london_st_thomas_df = import_region_data('Resources/LONDON_ST_THOMAS.csv')
mississauga_df = import_region_data('Resources/MISSISSAUGA.csv')
niagara_df = import_region_data('Resources/NIAGARA_REGION.csv')
northbay_df = import_region_data('Resources/NORTH_BAY.csv')
northumberland_df = import_region_data('Resources/NORTHUMBERLAND_HILLS.csv')
oakville_milton_df = import_region_data('Resources/OAKVILLE_MILTON.csv')
ontario_df = import_region_data('Resources/Ontario.csv')
ottawa_df = import_region_data('Resources/OTTAWA.csv')
peterborough_kawarthas_df = import_region_data('Resources/PETERBOROUGH_AND_KAWARTHAS.csv')
quinte_df = import_region_data('Resources/QUINTE_AND_DISTRICT.csv')
rideau_df = import_region_data('Resources/RIDEAU_ST_LAWRENCE.csv')
ss_marie_df = import_region_data('Resources/SAULT_STE_MARIE.csv')
simcoe_df = import_region_data('Resources/SIMCOE_AND_DISTRICT.csv')
sudbury_df = import_region_data('Resources/SUDBURY.csv')
tillsonburg_df = import_region_data('Resources/TILLSONBURG_DISTRICT.csv')
windsor_df = import_region_data('Resources/WINDSOR_ESSEX.csv')
woodstock_df = import_region_data('Resources/WOODSTOCK_INGERSOLL.csv')
all_regions = [bancroft_df, barrie_df, brantford_df, cambridge_df, toronto_df, grey_bruce_owen_sound_df, guelph_df, hamilton_burlington_df, huron_perth_df, kawartha_df, kingston_df, kitchener_waterloo_df,
               lakelands_df, london_st_thomas_df, mississauga_df, niagara_df, northbay_df, northumberland_df, oakville_milton_df, ontario_df, ottawa_df, peterborough_kawarthas_df, quinte_df, rideau_df,
               ss_marie_df, simcoe_df, sudbury_df, tillsonburg_df, windsor_df, woodstock_df
              ]

# %%
ontario_df.head()
# Out:
#          Composite_Benchmark_SA_Ontario  Single_Family_Benchmark_SA_Ontario  \
# Date
# 2005-01                        219800.0                            229800.0
# 2005-02                        222500.0                            232800.0
# 2005-03                        225400.0                            236100.0
# 2005-04                        229300.0                            240500.0
# 2005-05                        233000.0                            244700.0
#
#          One_Storey_Benchmark_SA_Ontario  Two_Storey_Benchmark_SA_Ontario  \
# Date
# 2005-01                         202500.0                         246800.0
# 2005-02                         203500.0                         250800.0
# 2005-03                         204100.0                         255500.0
# 2005-04                         207000.0                         260500.0
# 2005-05                         209500.0                         265500.0
#
#          Townhouse_Benchmark_SA_Ontario  Apartment_Benchmark_SA_Ontario
# Date
# 2005-01                        169100.0                        157600.0
# 2005-02                        170200.0                        161300.0
# 2005-03                        171600.0                        165300.0
# 2005-04                        173000.0                        168500.0
# 2005-05                        174200.0                        172400.0

# %%
all_regions_df = pd.concat(all_regions, axis=1)
all_regions_df.head()
# Out:
#          Composite_Benchmark_SA_BANCROFT_AND_AREA  \
# Date
# 2005-01                                  130000.0
# 2005-02                                  130300.0
# 2005-03                                  130200.0
# 2005-04                                  130300.0
# 2005-05                                  130500.0
#
#          Single_Family_Benchmark_SA_BANCROFT_AND_AREA  \
# Date
# 2005-01                                      130000.0
# 2005-02                                      130300.0
# 2005-03                                      130200.0
# 2005-04                                      130300.0
# 2005-05                                      130500.0
#
#          One_Storey_Benchmark_SA_BANCROFT_AND_AREA  \
# Date
# 2005-01                                   129100.0
# 2005-02                                   128300.0
# 2005-03                                   127600.0
# 2005-04                                   126900.0
# 2005-05                                   126300.0
#
#          Two_Storey_Benchmark_SA_BANCROFT_AND_AREA  \
# Date
# 2005-01                                   132400.0
# 2005-02                                   134800.0
# 2005-03                                   136300.0
# 2005-04                                   138600.0
# 2005-05                                   141300.0
#
#          Composite_Benchmark_SA_BARRIE_AND_AREA  \
# Date
# 2005-01                                214200.0
# 2005-02                                210100.0
# 2005-03                                209300.0
# 2005-04                                210600.0
# 2005-05                                211700.0
#
#          Single_Family_Benchmark_SA_BARRIE_AND_AREA  \
# Date
# 2005-01                                    223600.0
# 2005-02                                    219200.0
# 2005-03                                    217400.0
# 2005-04                                    219200.0
# 2005-05                                    220700.0
#
#          One_Storey_Benchmark_SA_BARRIE_AND_AREA  \
# Date
# 2005-01                                 222700.0
# 2005-02                                 216900.0
# 2005-03                                 212700.0
# 2005-04                                 216100.0
# 2005-05                                 216800.0
#
#          Two_Storey_Benchmark_SA_BARRIE_AND_AREA  \
# Date
# 2005-01                                 223400.0
# 2005-02                                 221400.0
# 2005-03                                 221100.0
# 2005-04                                 221700.0
# 2005-05                                 224100.0
#
#          Townhouse_Benchmark_SA_BARRIE_AND_AREA  \
# Date
# 2005-01                                145800.0
# 2005-02                                145600.0
# 2005-03                                145200.0
# 2005-04                                144100.0
# 2005-05                                143000.0
#
#          Apartment_Benchmark_SA_BARRIE_AND_AREA  ...  \
# Date                                             ...
# 2005-01                                158500.0  ...
# 2005-02                                159200.0  ...
# 2005-03                                159800.0  ...
# 2005-04                                160500.0  ...
# 2005-05                                161100.0  ...
#
#          Single_Family_Benchmark_SA_WINDSOR_ESSEX  \
# Date
# 2005-01                                  198600.0
# 2005-02                                  200700.0
# 2005-03                                  202600.0
# 2005-04                                  202400.0
# 2005-05                                  202200.0
#
#          One_Storey_Benchmark_SA_WINDSOR_ESSEX  \
# Date
# 2005-01                               193400.0
# 2005-02                               194000.0
# 2005-03                               194400.0
# 2005-04                               192900.0
# 2005-05                               191500.0
#
#          Two_Storey_Benchmark_SA_WINDSOR_ESSEX  \
# Date
# 2005-01                               202900.0
# 2005-02                               207100.0
# 2005-03                               209200.0
# 2005-04                               210700.0
# 2005-05                               211200.0
#
#          Townhouse_Benchmark_SA_WINDSOR_ESSEX  \
# Date
# 2005-01                              106200.0
# 2005-02                              106300.0
# 2005-03                              106600.0
# 2005-04                              106700.0
# 2005-05                              106900.0
#
#          Apartment_Benchmark_SA_WINDSOR_ESSEX  \
# Date
# 2005-01                              129300.0
# 2005-02                              128300.0
# 2005-03                              127400.0
# 2005-04                              126400.0
# 2005-05                              125500.0
#
#          Composite_Benchmark_SA_WOODSTOCK_INGERSOLL  \
# Date
# 2005-01                                    163200.0
# 2005-02                                    164400.0
# 2005-03                                    165500.0
# 2005-04                                    167200.0
# 2005-05                                    168800.0
#
#          Single_Family_Benchmark_SA_WOODSTOCK_INGERSOLL  \
# Date
# 2005-01                                        170000.0
# 2005-02                                        171400.0
# 2005-03                                        172600.0
# 2005-04                                        174600.0
# 2005-05                                        176500.0
#
#          One_Storey_Benchmark_SA_WOODSTOCK_INGERSOLL  \
# Date
# 2005-01                                     154000.0
# 2005-02                                     155600.0
# 2005-03                                     157300.0
# 2005-04                                     158300.0
# 2005-05                                     159400.0
#
#          Two_Storey_Benchmark_SA_WOODSTOCK_INGERSOLL  \
# Date
# 2005-01                                     183000.0
# 2005-02                                     184100.0
# 2005-03                                     185100.0
# 2005-04                                     187700.0
# 2005-05                                     190200.0
#
#          Townhouse_Benchmark_SA_WOODSTOCK_INGERSOLL
# Date
# 2005-01                                     96500.0
# 2005-02                                     96900.0
# 2005-03                                     97200.0
# 2005-04                                     97600.0
# 2005-05                                     98000.0
#
# [5 rows x 161 columns]

# %%
all_regions_df.drop_duplicates(inplace=True)
all_regions_df.dropna()
# Out:
#          Composite_Benchmark_SA_BANCROFT_AND_AREA  \
# Date
# 2005-01                                  130000.0
# 2005-02                                  130300.0
# 2005-03                                  130200.0
# 2005-04                                  130300.0
# 2005-05                                  130500.0
# ...                                           ...
# 2022-12                                  492900.0
# 2023-01                                  504200.0
# 2023-02                                  496900.0
# 2023-03                                  484200.0
# 2023-04                                  469000.0
#
#          Single_Family_Benchmark_SA_BANCROFT_AND_AREA  \
# Date
# 2005-01                                      130000.0
# 2005-02                                      130300.0
# 2005-03                                      130200.0
# 2005-04                                      130300.0
# 2005-05                                      130500.0
# ...                                               ...
# 2022-12                                      492900.0
# 2023-01                                      504200.0
# 2023-02                                      496900.0
# 2023-03                                      484200.0
# 2023-04                                      469000.0
#
#          One_Storey_Benchmark_SA_BANCROFT_AND_AREA  \
# Date
# 2005-01                                   129100.0
# 2005-02                                   128300.0
# 2005-03                                   127600.0
# 2005-04                                   126900.0
# 2005-05                                   126300.0
# ...                                            ...
# 2022-12                                   503800.0
# 2023-01                                   512500.0
# 2023-02                                   508000.0
# 2023-03                                   499800.0
# 2023-04                                   476600.0
#
#          Two_Storey_Benchmark_SA_BANCROFT_AND_AREA  \
# Date
# 2005-01                                   132400.0
# 2005-02                                   134800.0
# 2005-03                                   136300.0
# 2005-04                                   138600.0
# 2005-05                                   141300.0
# ...                                            ...
# 2022-12                                   456400.0
# 2023-01                                   474400.0
# 2023-02                                   465400.0
# 2023-03                                   454800.0
# 2023-04                                   454900.0
#
#          Composite_Benchmark_SA_BARRIE_AND_AREA  \
# Date
# 2005-01                                214200.0
# 2005-02                                210100.0
# 2005-03                                209300.0
# 2005-04                                210600.0
# 2005-05                                211700.0
# ...                                         ...
# 2022-12                                798500.0
# 2023-01                                780100.0
# 2023-02                                764800.0
# 2023-03                                766000.0
# 2023-04                                779200.0
#
#          Single_Family_Benchmark_SA_BARRIE_AND_AREA  \
# Date
# 2005-01                                    223600.0
# 2005-02                                    219200.0
# 2005-03                                    217400.0
# 2005-04                                    219200.0
# 2005-05                                    220700.0
# ...                                             ...
# 2022-12                                    837500.0
# 2023-01                                    819300.0
# 2023-02                                    802500.0
# 2023-03                                    805000.0
# 2023-04                                    821100.0
#
#          One_Storey_Benchmark_SA_BARRIE_AND_AREA  \
# Date
# 2005-01                                 222700.0
# 2005-02                                 216900.0
# 2005-03                                 212700.0
# 2005-04                                 216100.0
# 2005-05                                 216800.0
# ...                                          ...
# 2022-12                                 795400.0
# 2023-01                                 772800.0
# 2023-02                                 758400.0
# 2023-03                                 766000.0
# 2023-04                                 773500.0
#
#          Two_Storey_Benchmark_SA_BARRIE_AND_AREA  \
# Date
# 2005-01                                 223400.0
# 2005-02                                 221400.0
# 2005-03                                 221100.0
# 2005-04                                 221700.0
# 2005-05                                 224100.0
# ...                                          ...
# 2022-12                                 866500.0
# 2023-01                                 854400.0
# 2023-02                                 840300.0
# 2023-03                                 842100.0
# 2023-04                                 856900.0
#
#          Townhouse_Benchmark_SA_BARRIE_AND_AREA  \
# Date
# 2005-01                                145800.0
# 2005-02                                145600.0
# 2005-03                                145200.0
# 2005-04                                144100.0
# 2005-05                                143000.0
# ...                                         ...
# 2022-12                                582500.0
# 2023-01                                568900.0
# 2023-02                                562400.0
# 2023-03                                548000.0
# 2023-04                                553100.0
#
#          Apartment_Benchmark_SA_BARRIE_AND_AREA  ...  \
# Date                                             ...
# 2005-01                                158500.0  ...
# 2005-02                                159200.0  ...
# 2005-03                                159800.0  ...
# 2005-04                                160500.0  ...
# 2005-05                                161100.0  ...
# ...                                         ...  ...
# 2022-12                                520300.0  ...
# 2023-01                                501900.0  ...
# 2023-02                                512200.0  ...
# 2023-03                                534200.0  ...
# 2023-04                                531100.0  ...
#
#          Single_Family_Benchmark_SA_WINDSOR_ESSEX  \
# Date
# 2005-01                                  198600.0
# 2005-02                                  200700.0
# 2005-03                                  202600.0
# 2005-04                                  202400.0
# 2005-05                                  202200.0
# ...                                           ...
# 2022-12                                  622800.0
# 2023-01                                  620600.0
# 2023-02                                  631700.0
# 2023-03                                  611900.0
# 2023-04                                  593200.0
#
#          One_Storey_Benchmark_SA_WINDSOR_ESSEX  \
# Date
# 2005-01                               193400.0
# 2005-02                               194000.0
# 2005-03                               194400.0
# 2005-04                               192900.0
# 2005-05                               191500.0
# ...                                        ...
# 2022-12                               586600.0
# 2023-01                               593300.0
# 2023-02                               616400.0
# 2023-03                               604700.0
# 2023-04                               589000.0
#
#          Two_Storey_Benchmark_SA_WINDSOR_ESSEX  \
# Date
# 2005-01                               202900.0
# 2005-02                               207100.0
# 2005-03                               209200.0
# 2005-04                               210700.0
# 2005-05                               211200.0
# ...                                        ...
# 2022-12                               674800.0
# 2023-01                               661600.0
# 2023-02                               650700.0
# 2023-03                               625300.0
# 2023-04                               599200.0
#
#          Townhouse_Benchmark_SA_WINDSOR_ESSEX  \
# Date
# 2005-01                              106200.0
# 2005-02                              106300.0
# 2005-03                              106600.0
# 2005-04                              106700.0
# 2005-05                              106900.0
# ...                                       ...
# 2022-12                              390500.0
# 2023-01                              378800.0
# 2023-02                              377200.0
# 2023-03                              374100.0
# 2023-04                              379600.0
#
#          Apartment_Benchmark_SA_WINDSOR_ESSEX  \
# Date
# 2005-01                              129300.0
# 2005-02                              128300.0
# 2005-03                              127400.0
# 2005-04                              126400.0
# 2005-05                              125500.0
# ...                                       ...
# 2022-12                              397900.0
# 2023-01                              390300.0
# 2023-02                              394400.0
# 2023-03                              390100.0
# 2023-04                              383500.0
#
#          Composite_Benchmark_SA_WOODSTOCK_INGERSOLL  \
# Date
# 2005-01                                    163200.0
# 2005-02                                    164400.0
# 2005-03                                    165500.0
# 2005-04                                    167200.0
# 2005-05                                    168800.0
# ...                                             ...
# 2022-12                                    636200.0
# 2023-01                                    625100.0
# 2023-02                                    611500.0
# 2023-03                                    608400.0
# 2023-04                                    612300.0
#
#          Single_Family_Benchmark_SA_WOODSTOCK_INGERSOLL  \
# Date
# 2005-01                                        170000.0
# 2005-02                                        171400.0
# 2005-03                                        172600.0
# 2005-04                                        174600.0
# 2005-05                                        176500.0
# ...                                                 ...
# 2022-12                                        658000.0
# 2023-01                                        645900.0
# 2023-02                                        631700.0
# 2023-03                                        629400.0
# 2023-04                                        632400.0
#
#          One_Storey_Benchmark_SA_WOODSTOCK_INGERSOLL  \
# Date
# 2005-01                                     154000.0
# 2005-02                                     155600.0
# 2005-03                                     157300.0
# 2005-04                                     158300.0
# 2005-05                                     159400.0
# ...                                              ...
# 2022-12                                     588800.0
# 2023-01                                     583700.0
# 2023-02                                     571400.0
# 2023-03                                     562800.0
# 2023-04                                     557500.0
#
#          Two_Storey_Benchmark_SA_WOODSTOCK_INGERSOLL  \
# Date
# 2005-01                                     183000.0
# 2005-02                                     184100.0
# 2005-03                                     185100.0
# 2005-04                                     187700.0
# 2005-05                                     190200.0
# ...                                              ...
# 2022-12                                     703000.0
# 2023-01                                     684500.0
# 2023-02                                     670300.0
# 2023-03                                     675400.0
# 2023-04                                     679500.0
#
#          Townhouse_Benchmark_SA_WOODSTOCK_INGERSOLL
# Date
# 2005-01                                     96500.0
# 2005-02                                     96900.0
# 2005-03                                     97200.0
# 2005-04                                     97600.0
# 2005-05                                     98000.0
# ...                                             ...
# 2022-12                                    441400.0
# 2023-01                                    443200.0
# 2023-02                                    445900.0
# 2023-03                                    453400.0
# 2023-04                                    472100.0
#
# [220 rows x 161 columns]

# %%
benchmark_plot = all_regions_df.hvplot.line(
    x='Date', 
    xlabel='Date', 
    ylabel='Price Index', 
    title='Composite Benchmark',
    rot=90,
    height=800,
    width=2000,
    legend=False
).opts(
    fontsize={
        'title': 20, 
        'labels': 14, 
        'xticks': 5, 
        'yticks': 10,
    },
    yformatter=NumeralTickFormatter(format="0,0")
)
benchmark_plot
# Out:
# :NdOverlay   [Variable]
#    :Curve   [Date]   (value)

# %%
lumber_df = pd.read_csv(Path("Resources/lumber.csv"))
lumber_df['date'] = pd.to_datetime(lumber_df['date'])
lumber_df.set_index('date', inplace=True)
lumber_grouped_df = lumber_df.groupby(pd.Grouper(freq="M")).max()
lumber_grouped_df.index = lumber_grouped_df.index.strftime('%Y-%m')
lumber_grouped_df = lumber_grouped_df.rename(columns={' value': 'value'})

# %%
lumber_grouped_df.head()
# Out:
#          value
# date
# 1972-11  128.4
# 1972-12  144.0
# 1973-01  152.0
# 1973-02  163.4
# 1973-03  171.5

# %%
lumber_plot = lumber_grouped_df["value"].hvplot.line(
    x='date', 
    y='value', 
    xlabel='Date', 
    ylabel='Price', 
    title='Macrotrends Lumber Prices - 50 Year Historical Chart',
    line_color='blue',
    rot=90,
    height=800,
    width=2000
).opts(
    fontsize={
        'title': 20, 
        'labels': 14, 
        'xticks': 5, 
        'yticks': 10,
    },
    yformatter=NumeralTickFormatter(format="0,0")
)
lumber_plot
# Out:
# :Curve   [date]   (value)

# %%
wood_df = pd.read_csv(Path("Resources/WOOD.csv"))
wood_df['Date'] = pd.to_datetime(wood_df['Date'])
wood_df.set_index('Date', inplace=True)
wood_grouped_df = wood_df.groupby(pd.Grouper(freq="M")).max()
wood_grouped_df.index = wood_grouped_df.index.strftime('%Y-%m')

# %%
wood_grouped_df.head()
# Out:
#               Open       High        Low      Close  Adj Close  Volume
# Date
# 2008-06  49.150002  49.150002  48.750000  48.860001  37.981945    7000
# 2008-07  48.099998  48.549999  47.930000  48.529999  37.725414  120500
# 2008-08  49.320000  49.500000  49.029999  49.169998  38.222927   19400
# 2008-09  52.669998  52.669998  49.029999  49.919998  38.805954   35200
# 2008-10  44.880001  44.880001  44.180000  44.180000  34.343884   38600

# %%
wood_plot = wood_grouped_df["Close"].hvplot.line(
    x='Date', 
    y='Close', 
    xlabel='Date', 
    ylabel='Price', 
    title='iShares Global Timber & Forestry ETF',
    line_color='blue',
    rot=90,
    height=800,
    width=2000
).opts(
    fontsize={
        'title': 20, 
        'labels': 14, 
        'xticks': 5, 
        'yticks': 10,
    },
    yformatter=NumeralTickFormatter(format="0,0")
)
wood_plot
# Out:
# :Curve   [Date]   (Close)

# %%
xhb_df = pd.read_csv(Path("Resources/XHB.csv"))
xhb_df['Date'] = pd.to_datetime(xhb_df['Date'])
xhb_df.set_index('Date', inplace=True)
xhb_grouped_df = xhb_df.groupby(pd.Grouper(freq="M")).max()
xhb_grouped_df.index = xhb_grouped_df.index.strftime('%Y-%m')

# %%
xhb_grouped_df.head()
# Out:
#               Open       High        Low      Close  Adj Close   Volume
# Date
# 2006-02  45.810001  46.080002  45.180000  45.910000  38.730759   639200
# 2006-03  46.209999  46.389999  45.910000  46.139999  38.955757   908900
# 2006-04  46.060001  46.520000  45.660000  46.490002  39.251247   908400
# 2006-05  42.500000  42.639999  41.840000  42.349998  35.755878  1182900
# 2006-06  37.580002  37.669998  36.529999  37.439999  31.610374  1277000

# %%
xhb_plot = xhb_grouped_df["Close"].hvplot.line(
    x='Date', 
    y='Close', 
    xlabel='Date', 
    ylabel='Price', 
    title='SPDR S&P Homebuilders ETF',
    line_color='blue',
    rot=90,
    height=800,
    width=2000
).opts(
    fontsize={
        'title': 20, 
        'labels': 14, 
        'xticks': 5, 
        'yticks': 10,
    },
    yformatter=NumeralTickFormatter(format="0,0")
)
xhb_plot
# Out:
# :Curve   [Date]   (Close)

# %%
itb_df = pd.read_csv(Path("Resources/ITB.csv"))
itb_df['Date'] = pd.to_datetime(itb_df['Date'])
itb_df.set_index('Date', inplace=True)
itb_grouped_df = itb_df.groupby(pd.Grouper(freq="M")).max()
itb_grouped_df.index = itb_grouped_df.index.strftime('%Y-%m')

# %%
itb_grouped_df.head()
# Out:
#               Open       High        Low      Close  Adj Close  Volume
# Date
# 2006-05  49.650002  50.099998  49.130001  50.099998  44.535919   76200
# 2006-06  43.830002  43.830002  42.860001  43.380001  38.562260   46500
# 2006-07  39.299999  39.380001  38.889999  39.270000  34.940060  250000
# 2006-08  37.790001  38.330002  36.730000  37.150002  33.053802  294500
# 2006-09  38.689999  39.540001  38.020000  38.919998  34.689968  975900

# %%
itb_plot = itb_grouped_df["Close"].hvplot.line(
    x='Date', 
    y='Close', 
    xlabel='Date', 
    ylabel='Price', 
    title='iShares U.S. Home Construction ETF',
    line_color='blue',
    rot=90,
    height=800,
    width=2000
).opts(
    fontsize={
        'title': 20, 
        'labels': 14, 
        'xticks': 5, 
        'yticks': 10,
    },
    yformatter=NumeralTickFormatter(format="0,0")
)
itb_plot
# Out:
# :Curve   [Date]   (Close)

# %%
pd.read_csv(Path("Resources/consumerpriceindex_formatted.csv")).T.to_csv('Resources/consumerpriceindex_formatted_t.csv', header=False)
cpi_df = pd.read_csv(Path("Resources/consumerpriceindex_formatted_t.csv"))
cpi_df['Products and product groups 7'] = pd.to_datetime(cpi_df['Products and product groups 7'], format='%b-%y')
cpi_df.set_index('Products and product groups 7', inplace=True)
cpi_df.index = cpi_df.index.strftime('%Y-%m')

# %%
cpi_df.head()
# Out:
#                                All-items 8   Food  Shelter  \
# Products and product groups 7
# 2005-12                              108.0  107.4    110.5
# 2006-01                              108.9  107.9    111.8
# 2006-02                              108.5  107.9    111.7
# 2006-03                              108.6  108.1    111.9
# 2006-04                              109.1  108.1    112.2
#
#                                Household operations, furnishings and equipment  \
# Products and product groups 7
# 2005-12                                                                  102.2
# 2006-01                                                                  102.5
# 2006-02                                                                  102.3
# 2006-03                                                                  102.2
# 2006-04                                                                  102.1
#
#                                Clothing and footwear  Transportation  \
# Products and product groups 7
# 2005-12                                         97.1           113.1
# 2006-01                                         96.2           114.7
# 2006-02                                         95.7           112.7
# 2006-03                                         96.5           114.2
# 2006-04                                         95.6           117.9
#
#                                Health and personal care  \
# Products and product groups 7
# 2005-12                                           105.4
# 2006-01                                           105.4
# 2006-02                                           105.5
# 2006-03                                           105.7
# 2006-04                                           105.7
#
#                                Recreation, education and reading  \
# Products and product groups 7
# 2005-12                                                    100.8
# 2006-01                                                    100.9
# 2006-02                                                    100.7
# 2006-03                                                    100.7
# 2006-04                                                    100.7
#
#                                Alcoholic beverages, tobacco products and recreational cannabis  \
# Products and product groups 7
# 2005-12                                                                    119.9
# 2006-01                                                                    120.0
# 2006-02                                                                    120.5
# 2006-03                                                                    121.5
# 2006-04                                                                    121.9
#
#                                All-items excluding food  \
# Products and product groups 7
# 2005-12                                           108.2
# 2006-01                                           108.2
# 2006-02                                           108.0
# 2006-03                                           108.7
# 2006-04                                           109.5
#
#                                All-items excluding food and energy
# Products and product groups 7
# 2005-12                                                      106.0
# 2006-01                                                      106.2
# 2006-02                                                      106.3
# 2006-03                                                      106.5
# 2006-04                                                      106.6

# %%
cpi_plot = cpi_df.hvplot.line(
    x='Products and product groups 7', 
    xlabel='Date', 
    ylabel='Price', 
    title='Consumer Price Index',
    rot=90,
    height=800,
    width=2000
).opts(
    fontsize={
        'title': 20, 
        'labels': 14, 
        'xticks': 5, 
        'yticks': 10,
    },
    yformatter=NumeralTickFormatter(format="0,0")
)
cpi_plot
# Out:
# :NdOverlay   [Variable]
#    :Curve   [Products and product groups 7]   (value)

# %%
ir = pd.read_csv(Path("Resources/interestrateswithgaps.csv"))
ir['Date'] = pd.to_datetime(ir['Date'])
ir.set_index('Date', inplace=True)
ir_grouped_df = ir.groupby(pd.Grouper(freq="M")).last()
ir_grouped_df = ir_grouped_df.resample('M').last().ffill()
new_date_range = pd.date_range(start='2004-01-01', end='2023-06-30', freq='M')
ir_grouped_df = ir_grouped_df.reindex(new_date_range).ffill()
ir_grouped_df.index = ir_grouped_df.index.strftime('%Y-%m')

# %%
ir_grouped_df.tail()
# Out:
#          Bank rate  Target for the overnight rate
# 2023-02       4.75                            4.5
# 2023-03       4.75                            4.5
# 2023-04       4.75                            4.5
# 2023-05       4.75                            4.5
# 2023-06       4.75                            4.5

# %%
ir_plot = ir_grouped_df["Bank rate"].hvplot.line(
    x='Date', 
    y='Bank rate', 
    xlabel='Date', 
    ylabel='Price', 
    title='Bank Rate',
    line_color='blue',
    rot=90,
    height=800,
    width=2000
).opts(
    fontsize={
        'title': 20, 
        'labels': 14, 
        'xticks': 5, 
        'yticks': 10,
    },
    yformatter=NumeralTickFormatter(format="0,0")
)
ir_plot
# Out:
# :Curve   [Date]   (Bank rate)

# %%
most_values = pd.concat([all_regions_df, lumber_grouped_df, wood_grouped_df["Close"], xhb_grouped_df["Close"], itb_grouped_df["Close"], ir_grouped_df["Bank rate"]], axis = 1, join = 'inner')
cols = all_regions_df.columns.tolist()
cols.extend(['Lumber', 'Wood', 'XHB', 'ITB', "Bank Rate"])
most_values.columns = cols
all_values = pd.concat([most_values, cpi_df], axis =1 , join = 'inner')

# %%
all_values
# Out:
#          Composite_Benchmark_SA_BANCROFT_AND_AREA  \
# 2008-06                                  161400.0
# 2008-07                                  160800.0
# 2008-08                                  159300.0
# 2008-09                                  157300.0
# 2008-10                                  156600.0
# ...                                           ...
# 2022-12                                  492900.0
# 2023-01                                  504200.0
# 2023-02                                  496900.0
# 2023-03                                  484200.0
# 2023-04                                  469000.0
#
#          Single_Family_Benchmark_SA_BANCROFT_AND_AREA  \
# 2008-06                                      161400.0
# 2008-07                                      160800.0
# 2008-08                                      159300.0
# 2008-09                                      157300.0
# 2008-10                                      156600.0
# ...                                               ...
# 2022-12                                      492900.0
# 2023-01                                      504200.0
# 2023-02                                      496900.0
# 2023-03                                      484200.0
# 2023-04                                      469000.0
#
#          One_Storey_Benchmark_SA_BANCROFT_AND_AREA  \
# 2008-06                                   153600.0
# 2008-07                                   150800.0
# 2008-08                                   149600.0
# 2008-09                                   146300.0
# 2008-10                                   145500.0
# ...                                            ...
# 2022-12                                   503800.0
# 2023-01                                   512500.0
# 2023-02                                   508000.0
# 2023-03                                   499800.0
# 2023-04                                   476600.0
#
#          Two_Storey_Benchmark_SA_BANCROFT_AND_AREA  \
# 2008-06                                   180500.0
# 2008-07                                   183800.0
# 2008-08                                   182800.0
# 2008-09                                   186600.0
# 2008-10                                   188400.0
# ...                                            ...
# 2022-12                                   456400.0
# 2023-01                                   474400.0
# 2023-02                                   465400.0
# 2023-03                                   454800.0
# 2023-04                                   454900.0
#
#          Composite_Benchmark_SA_BARRIE_AND_AREA  \
# 2008-06                                249400.0
# 2008-07                                248000.0
# 2008-08                                246700.0
# 2008-09                                247100.0
# 2008-10                                246400.0
# ...                                         ...
# 2022-12                                798500.0
# 2023-01                                780100.0
# 2023-02                                764800.0
# 2023-03                                766000.0
# 2023-04                                779200.0
#
#          Single_Family_Benchmark_SA_BARRIE_AND_AREA  \
# 2008-06                                    258200.0
# 2008-07                                    256500.0
# 2008-08                                    254900.0
# 2008-09                                    255300.0
# 2008-10                                    254800.0
# ...                                             ...
# 2022-12                                    837500.0
# 2023-01                                    819300.0
# 2023-02                                    802500.0
# 2023-03                                    805000.0
# 2023-04                                    821100.0
#
#          One_Storey_Benchmark_SA_BARRIE_AND_AREA  \
# 2008-06                                 252300.0
# 2008-07                                 248100.0
# 2008-08                                 244900.0
# 2008-09                                 245900.0
# 2008-10                                 247600.0
# ...                                          ...
# 2022-12                                 795400.0
# 2023-01                                 772800.0
# 2023-02                                 758400.0
# 2023-03                                 766000.0
# 2023-04                                 773500.0
#
#          Two_Storey_Benchmark_SA_BARRIE_AND_AREA  \
# 2008-06                                 262800.0
# 2008-07                                 263000.0
# 2008-08                                 262700.0
# 2008-09                                 262400.0
# 2008-10                                 260700.0
# ...                                          ...
# 2022-12                                 866500.0
# 2023-01                                 854400.0
# 2023-02                                 840300.0
# 2023-03                                 842100.0
# 2023-04                                 856900.0
#
#          Townhouse_Benchmark_SA_BARRIE_AND_AREA  \
# 2008-06                                172400.0
# 2008-07                                173200.0
# 2008-08                                173900.0
# 2008-09                                174100.0
# 2008-10                                173600.0
# ...                                         ...
# 2022-12                                582500.0
# 2023-01                                568900.0
# 2023-02                                562400.0
# 2023-03                                548000.0
# 2023-04                                553100.0
#
#          Apartment_Benchmark_SA_BARRIE_AND_AREA  ...   Food  Shelter  \
# 2008-06                                192900.0  ...  115.2    122.3
# 2008-07                                193800.0  ...  116.0    123.3
# 2008-08                                195100.0  ...  116.8    123.8
# 2008-09                                195800.0  ...  118.0    123.1
# 2008-10                                191700.0  ...  118.5    123.2
# ...                                         ...  ...    ...      ...
# 2022-12                                520300.0  ...  178.7    167.8
# 2023-01                                501900.0  ...  180.4    168.0
# 2023-02                                512200.0  ...  181.2    168.3
# 2023-03                                534200.0  ...  182.0    168.9
# 2023-04                                531100.0  ...  182.9    169.9
#
#          Household operations, furnishings and equipment  \
# 2008-06                                            104.3
# 2008-07                                            104.5
# 2008-08                                            104.5
# 2008-09                                            105.4
# 2008-10                                            105.2
# ...                                                  ...
# 2022-12                                            132.7
# 2023-01                                            132.2
# 2023-02                                            133.3
# 2023-03                                            133.2
# 2023-04                                            133.4
#
#          Clothing and footwear  Transportation  Health and personal care  \
# 2008-06                   94.0           124.0                     108.3
# 2008-07                   94.8           124.0                     108.4
# 2008-08                   94.3           122.4                     109.3
# 2008-09                   94.0           122.3                     109.2
# 2008-10                   92.7           118.3                     109.3
# ...                        ...             ...                       ...
# 2022-12                   96.1           168.6                     142.0
# 2023-01                   95.8           168.2                     142.7
# 2023-02                   96.6           166.9                     143.4
# 2023-03                   96.9           166.5                     144.2
# 2023-04                   96.7           168.3                     144.9
#
#          Recreation, education and reading  \
# 2008-06                              102.3
# 2008-07                              102.2
# 2008-08                              102.5
# 2008-09                              102.4
# 2008-10                              102.2
# ...                                    ...
# 2022-12                              124.6
# 2023-01                              124.6
# 2023-02                              124.3
# 2023-03                              124.9
# 2023-04                              125.5
#
#          Alcoholic beverages, tobacco products and recreational cannabis  \
# 2008-06                                              127.7
# 2008-07                                              127.6
# 2008-08                                              127.5
# 2008-09                                              128.0
# 2008-10                                              128.0
# ...                                                    ...
# 2022-12                                              185.2
# 2023-01                                              186.5
# 2023-02                                              187.4
# 2023-03                                              188.7
# 2023-04                                              189.1
#
#          All-items excluding food  All-items excluding food and energy
# 2008-06                     114.9                                110.3
# 2008-07                     115.2                                110.4
# 2008-08                     115.0                                110.6
# 2008-09                     115.0                                110.6
# 2008-10                     113.9                                110.4
# ...                           ...                                  ...
# 2022-12                     149.8                                144.8
# 2023-01                     149.9                                145.0
# 2023-02                     150.1                                145.5
# 2023-03                     150.4                                146.0
# 2023-04                     151.3                                146.5
#
# [179 rows x 177 columns]

# %%
all_values.index.name = 'date'

# %%
all_values.to_csv('Resources/all_values_superset.csv', index=True)
